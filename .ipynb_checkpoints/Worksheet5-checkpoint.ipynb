# %%
import pandas as pd
import matplotlib as plb
import numpy as np

# %%
df=pd.read_csv("student.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df=pd.readcsv("student.csv")
#
# AttributeError: module 'pandas' has no attribute 'readcsv'
